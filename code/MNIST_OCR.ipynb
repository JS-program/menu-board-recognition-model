# %%
import tensorflow.keras as keras
from keras.datasets import mnist
from keras.models import Sequential, load_model
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import Adam
from keras.utils import np_utils

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train.reshape(60000, 784).astype("float32")
X_test = X_test.reshape(10000, 784).astype("float")
X_train /= 255
X_test /= 255

# %%
y_train = np_utils.to_categorical(y_train, 10)
y_test = np_utils.to_categorical(y_test, 10)

# %%
model = Sequential()
model.add(Dense(512, input_shape=(784,)))
model.add(Activation("relu"))
model.add(Dropout(0.2))
model.add(Dense(512))
model.add(Activation("relu"))
model.add(Dropout(0.2))
model.add(Dense(10))
model.add(Activation("softmax"))

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam(),metrics=['accuracy'])

# %%
hist = model.fit(X_train, y_train, epochs=100)
score = model.evaluate(X_test, y_test, verbose=1)
print("loss=", score[0])
print("accuracy=", score[1])
# Out:
# Epoch 1/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.2146 - accuracy: 0.9350
# Epoch 2/100
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.1079 - accuracy: 0.9657
# Epoch 3/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0805 - accuracy: 0.9753
# Epoch 4/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0665 - accuracy: 0.9791
# Epoch 5/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0576 - accuracy: 0.9821
# Epoch 6/100
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.0508 - accuracy: 0.9839
# Epoch 7/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0498 - accuracy: 0.9851
# Epoch 8/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0422 - accuracy: 0.9867
# Epoch 9/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0387 - accuracy: 0.9879
# Epoch 10/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0384 - accuracy: 0.9881
# Epoch 11/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0380 - accuracy: 0.9887
# Epoch 12/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0325 - accuracy: 0.9902
# Epoch 13/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0311 - accuracy: 0.9909
# Epoch 14/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0319 - accuracy: 0.9913
# Epoch 15/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0291 - accuracy: 0.9916
# Epoch 16/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0308 - accuracy: 0.9911
# Epoch 17/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0302 - accuracy: 0.9916
# Epoch 18/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0294 - accuracy: 0.9921
# Epoch 19/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0284 - accuracy: 0.9922
# Epoch 20/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0287 - accuracy: 0.9920
# Epoch 21/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0275 - accuracy: 0.9926
# Epoch 22/100
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0245 - accuracy: 0.9934
# Epoch 23/100
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0261 - accuracy: 0.9933
# Epoch 24/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0262 - accuracy: 0.9933
# Epoch 25/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0223 - accuracy: 0.9942
# Epoch 26/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0277 - accuracy: 0.9931
# Epoch 27/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0257 - accuracy: 0.9935
# Epoch 28/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0226 - accuracy: 0.9941
# Epoch 29/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0234 - accuracy: 0.9941
# Epoch 30/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0265 - accuracy: 0.9935
# Epoch 31/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0249 - accuracy: 0.9945
# Epoch 32/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0244 - accuracy: 0.9945
# Epoch 33/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0243 - accuracy: 0.9944
# Epoch 34/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0223 - accuracy: 0.9948
# Epoch 35/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0236 - accuracy: 0.9945
# Epoch 36/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0245 - accuracy: 0.9944
# Epoch 37/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0236 - accuracy: 0.9948
# Epoch 38/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0237 - accuracy: 0.9945
# Epoch 39/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0231 - accuracy: 0.9947
# Epoch 40/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0208 - accuracy: 0.9955
# Epoch 41/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0219 - accuracy: 0.9952
# Epoch 42/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0242 - accuracy: 0.9952
# Epoch 43/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0243 - accuracy: 0.9953
# Epoch 44/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0229 - accuracy: 0.9951
# Epoch 45/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0235 - accuracy: 0.9952
# Epoch 46/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0191 - accuracy: 0.9958
# Epoch 47/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0230 - accuracy: 0.9952
# Epoch 48/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0199 - accuracy: 0.9961
# Epoch 49/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0201 - accuracy: 0.9957
# Epoch 50/100
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0218 - accuracy: 0.9956
# Epoch 51/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0288 - accuracy: 0.9951
# Epoch 52/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0224 - accuracy: 0.9960
# Epoch 53/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0235 - accuracy: 0.9958
# Epoch 54/100
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0212 - accuracy: 0.9960
# Epoch 55/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0294 - accuracy: 0.9951
# Epoch 56/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0251 - accuracy: 0.9955
# Epoch 57/100
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0215 - accuracy: 0.9959
# Epoch 58/100
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0270 - accuracy: 0.9952
# Epoch 59/100
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0257 - accuracy: 0.9955
# Epoch 60/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0179 - accuracy: 0.9966
# Epoch 61/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0277 - accuracy: 0.9955s - loss: 0.0280 -
# Epoch 62/100
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0204 - accuracy: 0.9962
# Epoch 63/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0235 - accuracy: 0.9959
# Epoch 64/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0197 - accuracy: 0.9963
# Epoch 65/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0203 - accuracy: 0.9964
# Epoch 66/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0230 - accuracy: 0.9963
# Epoch 67/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0239 - accuracy: 0.9961
# Epoch 68/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0259 - accuracy: 0.9960
# Epoch 69/100
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0221 - accuracy: 0.9965
# Epoch 70/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0243 - accuracy: 0.9963
# Epoch 71/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0229 - accuracy: 0.9964
# Epoch 72/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0262 - accuracy: 0.9960
# Epoch 73/100
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.0203 - accuracy: 0.9966
# Epoch 74/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0221 - accuracy: 0.9964
# Epoch 75/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0215 - accuracy: 0.9964
# Epoch 76/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0252 - accuracy: 0.9966
# Epoch 77/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0198 - accuracy: 0.9967
# Epoch 78/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0248 - accuracy: 0.9962
# Epoch 79/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0247 - accuracy: 0.9964
# Epoch 80/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0183 - accuracy: 0.9972
# Epoch 81/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0226 - accuracy: 0.9965
# Epoch 82/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0206 - accuracy: 0.9966
# Epoch 83/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0227 - accuracy: 0.9963
# Epoch 84/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0233 - accuracy: 0.9965
# Epoch 85/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0248 - accuracy: 0.9964
# Epoch 86/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0216 - accuracy: 0.9966
# Epoch 87/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0175 - accuracy: 0.9969
# Epoch 88/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0228 - accuracy: 0.9967
# Epoch 89/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0228 - accuracy: 0.9968
# Epoch 90/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0251 - accuracy: 0.9967
# Epoch 91/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0196 - accuracy: 0.9969
# Epoch 92/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0263 - accuracy: 0.9964
# Epoch 93/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0196 - accuracy: 0.9973
# Epoch 94/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0262 - accuracy: 0.9967
# Epoch 95/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0207 - accuracy: 0.9969s - loss: 0.0207 - accu
# Epoch 96/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0248 - accuracy: 0.9966
# Epoch 97/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0240 - accuracy: 0.9972
# Epoch 98/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0198 - accuracy: 0.9974
# Epoch 99/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0210 - accuracy: 0.9968
# Epoch 100/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0271 - accuracy: 0.9963
# 10000/10000 [==============================] - 0s 23us/step
# loss= 0.31313416893912827
# accuracy= 0.9835000038146973

# %%
model.save("keras_mnist.h5")
print("keras_mnist Image Classifier Model Save OK")
# Out:
# keras_mnist Image Classifier Model Save OK
